# %% [markdown]
# <a href="https://colab.research.google.com/github/sumit7999/sumit7999/blob/main/Matplotlib_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Matplotlib Exercises**

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
plt.show()

# %% [markdown]
# # Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y)
axes.set_xlabel("X")
axes.set_ylabel("Y")
axes.set_title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.2,0.2])

ax1.plot(x,y)
ax1.set_xlabel("X")
ax1.set_ylabel("Y")

ax2.plot(x,y)
ax2.set_xlabel("X")
ax2.set_ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# #  Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.4,0.4])

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**![matplotlib (1).png](data:image/png;base64,...)

# %%
ax1.plot(x,z,"b")
ax1.set_xlabel("X")
ax1.set_ylabel("Z")

ax2.plot(x,y,"b")
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
ax2.set_xlabel("X")
ax2.set_ylabel("Y")
ax2.set_title("zoom")
fig

# %% [markdown]
#  Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**
#
# ![matplotlib2.png (2).png](data:image/png;base64,...)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**
#
# ![matplotlib 3).png.png](data:image/png;base64,...)

# %%
axes[0].plot(x,y,"b",lw=3,ls="--")
axes[1].plot(x,z,"r",lw=3)
fig.tight_layout()
fig

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**
#
# ![matplotlib (4).png.png](data:image/png;base64,...)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(12,2))
axes[0].plot(x,y,"b",lw="5")
axes[0].set_xlabel("x")
axes[0].set_ylabel("y")

axes[1].plot(x,z,"r",lw=3,ls="--")
axes[1].set_ylabel("z")
axes[1].set_xlabel("x")
# Out:
# Text(0.5, 0, 'x')
