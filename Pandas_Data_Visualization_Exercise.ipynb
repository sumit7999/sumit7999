# %% [markdown]
# <a href="https://colab.research.google.com/github/sumit7999/sumit7999/blob/main/Pandas_Data_Visualization_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Data Visualization Exercise

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('/content/df3.txt')
# %matplotlib inline
import seaborn as sns

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# # ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**
# ![p1.png](data:image/png;base64,...)

# %%
df3.plot.scatter(x="a",y="b",figsize=(12,3),s=50,color="red")

# %% [markdown]
# # ** Create a histogram of the 'a' column.**
# ![p2.png](data:image/png;base64,...)

# %%
df3["a"].hist()

# %% [markdown]
# # ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***
# ![p3.png](data:image/png;base64,...)

# %%
plt.style.use("ggplot")
df3["a"].hist(bins=25,alpha=0.5)

# %% [markdown]
# # ** Create a boxplot comparing the a and b columns.**
# ![p4.png](data:image/png;base64,...)

# %%
df3[["a","b"]].plot.box()

# %% [markdown]
# # ** Create a kde plot of the 'd' column **
# ![p5.png](data:image/png;base64,...)

# %%
df3["d"].plot.kde()

# %% [markdown]
# # ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**
# ![p6.png](data:image/png;base64,...)

# %%
df3["d"].plot.density(lw=5,ls=":")

# %% [markdown]
# # * Create an area plot of all the columns for just the rows up to 30.
# ![p7.png](data:image/png;base64,...)

# %%
df3.loc[0:30].plot.area(alpha=0.5)

# %% [markdown]
# #Display the legend outside of the plot as shown below?**
#
# ![p8.png](data:image/png;base64,...)

# %%
f = plt.figure()
df3.loc[0:30].plot.area(alpha=0.4,ax=f.gca())
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
